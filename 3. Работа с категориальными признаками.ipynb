# %% [markdown]
# **В этом блокноте используется файл с очищенными данными, сохраненный на предыдущем этапе.**

# %%
# !pip install gdown==4.6.0
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.7.3
#     Uninstalling gdown-4.7.3:
#       Successfully uninstalled gdown-4.7.3
# ...

# %%
! gdown 1nyKvsUfhqxnlY8nElzLZcEG2-_aRtXBy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1nyKvsUfhqxnlY8nElzLZcEG2-_aRtXBy
# To: /content/df_cleared.csv
# 100% 950k/950k [00:00<00:00, 99.8MB/s]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/df_cleared.csv')

# %%
 df['MS SubClass']
# Out:
# 0       20
# 1       20
# 2       20
# 3       20
# 4       60
#         ..
# 2920    80
# 2921    20
# 2922    85
# 2923    20
# 2924    60
# Name: MS SubClass, Length: 2925, dtype: int64

# %%
df['MS SubClass']  = df['MS SubClass'].apply(str)

# %%
df.select_dtypes(include = 'object')
# Out:
#      MS SubClass MS Zoning Street Lot Shape Land Contour Utilities Lot Config  \
# 0             20        RL   Pave       IR1          Lvl    AllPub     Corner
# 1             20        RH   Pave       Reg          Lvl    AllPub     Inside
# 2             20        RL   Pave       IR1          Lvl    AllPub     Corner
# 3             20        RL   Pave       Reg          Lvl    AllPub     Corner
# 4             60        RL   Pave       IR1          Lvl    AllPub     Inside
# ...          ...       ...    ...       ...          ...       ...        ...
# 2920          80        RL   Pave       IR1          Lvl    AllPub    CulDSac
# 2921          20        RL   Pave       IR1          Low    AllPub     Inside
# 2922          85        RL   Pave       Reg          Lvl    AllPub     Inside
# 2923          20        RL   Pave       Reg          Lvl    AllPub     Inside
# 2924          60        RL   Pave       Reg          Lvl    AllPub     Inside
#
# ...

# %%
object_df = df.select_dtypes(include = 'object')

# %%
numeric_df = df.select_dtypes(exclude = 'object')

# %%
df_object_dummies = pd.get_dummies(object_df, drop_first =True)

# %%
final_df = pd.concat([numeric_df, df_object_dummies], axis =1)

# %%
final_df.to_csv('/content/final_df.csv', index = False)
